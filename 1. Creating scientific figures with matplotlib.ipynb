# %% [markdown]
# First, our standard imports:

# %%
# %matplotlib inline
from IPython.display import Image

import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.rc('font', family='sans serif', size=16)

# %% [markdown]
# # Task 1. X-ray units for photons
#
# When we look at the X-ray radiation from the black holes, we usually use two different units for the x axis: either photon wavelength in <a href='https://en.wikipedia.org/wiki/Angstrom'>Angstrom</a>, or photon energy expressed in keV (kilo <a href='https://en.wikipedia.org/wiki/Electronvolt'>electronovolt</a>).
#
# You can look at examples in published work about some black holes we will be looking at, for example Mrk 509: https://arxiv.org/pdf/1812.03194.pdf or NGC 4051: https://arxiv.org/pdf/1112.5126.pdf. These are some scientific papers and any work will do is meant to end up in a publication like this. No need to read these, just look at the figures for now :)

# %% [markdown]
# ### The data
#
# We will simulate a coronal power law emission from an accretion disk. Our data will be:

# %%
x = np.linspace(0.1, 10, 100)
y = np.power(x, -2)

# %% [markdown]
# ### The assignment
#
# You will create a <b>log-log plot</b> of this simulated emission from a black hole that will be expressed in <b>keV units on the bottom x axis and Angstrom units on the top x axis </b>.
#
# This <a href='https://matplotlib.org/stable/gallery/subplots_axes_and_figures/secondary_axis.html'>example on matplotlib website</a> should be helpful. You will probably want to develop the following functions that will convert between the physics units:

# %%
def keV2ang(x):
    #
def ang2keV(x):
    #

# %% [markdown]
# Before you proceed to making the plot, you should check if you functions are correct.
# One way to check if your function is correct is by first calculating by hand what it should return for a specific argument. From physics we know that:
# keV2ang(1)=12.398 and ang2keV(12.398)=1  (do you understand why?). Make sure that this is how your functions work.

# %% [markdown]
# Your finished figure should look something like this:

# %%
Image("xplot.png", width=600)

# %% [markdown]
# # Task 2. Creating a "corner" plot
# In this short assignment you will create a "corner" plot, which is a really nice way of visualizing multi-dimensional histograms. In this notebook, we'll deal with the 2-dimensional case.
# If you still have trouble understanding what a histogram is, do read up on it!
#
# ### The data
# Using numpy we generate a 2-dimensional Gaussian distribution, with a strong covariance between the two variables.

# %%
mean = [0, 0]
cov  = [[1, 1], [1, 2]]  # covariance matrix

x, y = np.random.multivariate_normal(mean, cov, 10000)

# %% [markdown]
# ### The assignment
# Create a "corner" plot displaying the 2-D Gaussian data above. This should include the following elements:
#
# A histogram of the x-data
# A histogram of the y-data
# A "density" plot of the x, y data. This can be a scatter plot with some transparency set (e.g. alpha=)
#
# You may find <a href='https://stackoverflow.com/questions/4209467/matplotlib-share-x-axis-but-dont-show-x-axis-tick-labels-for-both-just-one'> this command </a>(courtesy of StackOverflow):
#
# <code>plt.setp(ax1.get_xticklabels(), visible=False)</code>
#
# useful for hiding the ticklabels for ax1 while sharex=True between ax1 and ax2, but still keeping ticklabels for ax2. A similar thing can be done for yticklabels. You can also use orientation='horizontal' in a hist plot to rotate the histogram 90 degrees.
#
# Finally, save the figure using the plt.savefig command. Some possible output formats are .pdf, or .png. For outputting figures to include in a paper, for example, .pdf is usually the way to go. Don't forget to set bbox_inches='tight' when saving your figure, so that everything is nicely formatted (try saving a figure with and without that option to see how much of a difference it makes!)
#
# The final output should look something like this (but does not need to look identical):

# %%
Image("plot.png")

# %%
'''
Fill-in code here.

First, create a figure using plt.figure
Then add the three subplots using plt.subplot(nrow, ncol, index), 
sharing axes where appropriate (i.e. sharex between the density 
plot and x-hist, sharey between density plot and y-hist)

Also, hide the ticklabels for the x-axis of the x-hist and 
the y-axis of the y-hist. The command above should be helpful.
'''




'''
Then,
1. Generate a scatterplot for the bottom-left subplot, adjusting 
   colors/opacity as necessary.
2. Generate a histogram for the x-data in the top-left subplot
3. Generate a histogram for the y-data in the bottom-right subplot.
   Rotate 90-degrees by setting the orientation to horizontal.
   
Don't forget to call fig.tight_layout() to keep the subplots nice & tidy!

Finally, save your figure using plt.savefig
'''
